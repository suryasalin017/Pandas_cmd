# %% [markdown]
# <a href="https://colab.research.google.com/github/suryasalin017/Pandas_cmd/blob/main/Pandas_cmd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df[['salary','phd',]].mean()
# Out:
# salary    108023.782051
# phd           19.705128
# dtype: float64

# %%
df[['salary','phd',]].median()
# Out:
# salary    104671.0
# phd           18.5
# dtype: float64

# %%
df[['salary','phd',]].mode()
# Out:
#    salary  phd
# 0   92000    4

# %%
df[['salary','phd',]].var()
# Out:
# salary    8.005313e+08
# phd       1.562106e+02
# dtype: float64

# %%
df[['salary','phd',]].std()
# Out:
# salary    28293.661022
# phd          12.498425
# dtype: float64

# %%
df[['salary','phd',]].skew()
# Out:
# salary    0.452103
# phd       0.634366
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    phd  service  salary
# 0    4        3   92000

# %%
df.median(numeric_only=True)
# Out:
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df[df['salary']>50000]  #filter the record where the salary is greater than 50000 in df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:10,0:3]
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
df.iloc[0:2,[1,3,5]]
# Out:
#   discipline  service  salary
# 0          B       49  186960
# 1          A        6   93000

# %%
# prompt: i want to select 2 rows and 1,3,5 columns

df.iloc[0:2,[1,3,5]]
# Out:
#   discipline  service  salary
# 0          B       49  186960
# 1          A        6   93000

# %%
df.loc[1,'salary']
# Out:
# 93000

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df['rank'].max()
# Out:
# 'Prof'

# %%
df['salary'].min()
# Out:
# 57800

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df['sex'].mode()
# Out:
# 0    Female
# 1      Male
# Name: sex, dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      39
# Female    39
# Name: count, dtype: int64

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
df.select_dtypes(include=['number']).columns
# Out:
# Index(['phd', 'service', 'salary'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
